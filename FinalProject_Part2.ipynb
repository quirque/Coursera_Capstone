# %% [markdown]
# # Applied Data Science Capstone &ndash; Final Project

# %% [markdown]
# ## Preface
#
# This notebook is being provided to fulfill the requirements of the final project for the Coursera **Applied Data Science Capstone** course.

# %% [markdown]
# # Data

# %% [markdown]
# The dataset that we will be using is from FourSquare.
# FourSquare data contains information on numerous points of interest in the city under investigation,
# with categories such as restaurants, parks, and schools.
#
# Many of the previous projects in this course have used neighborhoods as they are defined
# by exernal datasets. These external datasets have defined neighborhoods by such arbitrary
# measures as postal codes and historical/political districts. It does not seem that this
# always represents a good measure of what constitutes a neighborhood.
#
# I will be using the FourSquare data itself to define neighborhoods based on
# where points of interest are located geographically. I will be using clustering algorithms
# as part of this process, and will specifically be using the latitude and longitude
# fields from the FourSquare data.
#
# Once the neighborhoods have been defined, I will dig deeper into the characteristics
# of each point of interest, and attempt to understand what major amenities define each
# neighborhood.

# %% [markdown]
# ## Libraries

# %% [markdown]
# To implement the investigation of the neighborhoods in Stamford, CT, the following Python
# libraries and web services will be used:
# - Numpy and Pandas (for data analysis)
# - GeoPy (for location services)
# - Requests (to request data from web services, such as FourSquare)
# - Matplotlib (for plotting)
# - Sklearn (for machine learning, such as clustering algorithms)
# - Folium (to create maps)
# - Shapely (to deal with mapping geometry)
# - FourSquare (to provide data on points of interest)

# %% [markdown]
# ### Setup

# %% [markdown]
# First we download all the dependencies that we will need.

# %%
import numpy as np

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import math
import json

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests
from pandas import json_normalize # transform JSON file into a pandas dataframe (was pandas.io.json)

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

from shapely.geometry import shape, GeometryCollection, Point, Polygon
import shapely

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Stamford, CT.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>geo_explorer</em>, as shown below.

# %%
address = 'Stamford, CT'

geolocator = Nominatim(user_agent="geo_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of Stamford, CT are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Stamford, CT are 41.0534302, -73.5387341.

# %% [markdown]
# #### Create a map of Stamford with neighborhoods superimposed on top.

# %%
map_stamford_empty = folium.Map(location=[latitude, longitude], zoom_start=7)

state_geo_file = 'Connecticut.geojson'
city_geo_file = 'StamfordCT.geojson'

def geo_style_state(feature):
    return {
        # Border (weight is pixels); Also: stroke (bool to disable), lineCap, lineJoin, dashArray, dashOffset
        'color': '#000000', 'weight': 1.2, 'opacity': 0.2,
        # Fill; Also: fill (bool to disable), fillRule (determines inside of shape), bubblingMouseEvents
        'fillColor': '#0000ff', 'fillOpacity': 0.05
    }
def geo_highlight_state(feature):
    return {
        'fillOpacity': 0.1
    }

def geo_style_stamford(feature):
    return {
        'fillOpacity': 0.2, 'weight': 1.6, 'fillColor': '#00cc00'
    }

def geo_highlight_stamford(feature):
    return {
        'fillOpacity': 0.08
    }

def geo_style_rect(feature):
    return {
        'fillOpacity': 0, 'weight': 1.2, 'fillColor': '#00cccc'
    }

# Add overlay to show where city is
geo_ct = folium.GeoJson(state_geo_file, name='Connecticut', style_function=geo_style_state,
              highlight_function=geo_highlight_state, # tooltip="Connecticut",
              overlay=True, control=True, show=True).add_to(map_stamford_empty)
geo = folium.GeoJson(city_geo_file, name='Stamford, CT', style_function=geo_style_stamford,
              highlight_function=geo_highlight_stamford, tooltip="Stamford, CT",
              overlay=True, control=True, show=True).add_to(map_stamford_empty)

# CircleMarker does NOT have a style_function
folium.vector_layers.CircleMarker((latitude, longitude), radius=4, weight=1,
                                  fill=True, fill_opacity=1.0, fill_color="#000000",
                                  color="#000000", tooltip="City").add_to(map_stamford_empty)

lc = folium.map.LayerControl(position='topright').add_to(map_stamford_empty) #, collapsed=True, autoZIndex=True, **kwargs)

map_stamford_empty
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'BOGTGAFH5WKN13HQNJU0K5U3ZEUS1DLFI5JU0P2CX1ZTQGBE'
CLIENT_SECRET = '5MIOG3NT1VQ22FLEJPQJ1RND2QAFVF5QEMBXATCLXNHOOBRZ'
VERSION = '20180605' # Foursquare API version

print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: BOGTGAFH5WKN13HQNJU0K5U3ZEUS1DLFI5JU0P2CX1ZTQGBE
# CLIENT_SECRET:5MIOG3NT1VQ22FLEJPQJ1RND2QAFVF5QEMBXATCLXNHOOBRZ

# %%
LIMIT = 100
radius = 1000

# To get a JSON struct of categories:
# GET https://api.foursquare.com/v2/venues/categories
# Docs: https://developer.foursquare.com/docs/api-reference/venues/categories

# Extra params
# section = food, drinks, coffee, shops, arts, outdoors, sights, trending, nextVenues
# categoryId = <>
# https://developer.foursquare.com/docs/api/venues/categories = get a JSON representation of all categories (in tree)
# These are the top-level category IDs
#  4d4b7104d754a06370d81259 = Arts & Entertainment
#  4d4b7105d754a06372d81259 = College & University
#  4d4b7105d754a06373d81259 = Event
#  4d4b7105d754a06374d81259 = Food
#  4d4b7105d754a06376d81259 = Nightlife Spot (subs = Bar, Brewery, Lounge, Night Market, Nightclub, Other Nightlife, Strip Club)
#  4d4b7105d754a06377d81259 = Outdoors & Recreation
#  4d4b7105d754a06375d81259 = Professional & Other Places (incl Medical Center, School, Spiritual Center)
#  4e67e38e036454776db1fb3a = Residence (subs = Assisted Living, Home (private), Housing Development, Residential Building (Apartment / Condo), Trailer Park)
#  4d4b7105d754a06378d81259 = Shop & Service
#  4d4b7105d754a06379d81259 = Travel & Transport

url_params = "&time=any&day=any"

# %% [markdown]
# #### Now, let's get some venues that are in the search radius.

# %% [markdown]
# First, create the GET request URL.

# %%
def make_url(latitude, longitude, radius, offset=0, category_id=None):
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}" \
          "&v={}&ll={},{}&radius={}&offset={}&limit={}".format(
        CLIENT_ID, CLIENT_SECRET, VERSION,
        latitude, longitude,
        radius, offset, LIMIT)
    if category_id:
        url += "&categoryId={}".format(category_id)
    # sortByDistance=1  # distance instead of 'relevance'
    url += url_params
    return url

# %%
offset = 0
url = make_url(latitude, longitude, radius, offset)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=BOGTGAFH5WKN13HQNJU0K5U3ZEUS1DLFI5JU0P2CX1ZTQGBE&client_secret=5MIOG3NT1VQ22FLEJPQJ1RND2QAFVF5QEMBXATCLXNHOOBRZ&v=20180605&ll=41.0534302,-73.5387341&radius=1000&offset=0&limit=100&time=any&day=any'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f398b10c84c6d0398b2b3ad'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Downtown Stamford',
#   'headerFullLocation': 'Downtown Stamford, Stamford',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 120,
#   'suggestedBounds': {'ne': {'lat': 41.06243020900001,
#     'lng': -73.52682157478513},
#    'sw': {'lat': 41.04443019099999, 'lng': -73.55064662521487}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56ac70b2498ebfb7f369e6af',
#        'name': 'Kashi Stamford',
#        'location': {'address': '131 Summer St',
#         'lat': 41.05431965539036,
#         'lng': -73.54061792432401,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05431965539036,
#           'lng': -73.54061792432401}],
#         'distance': 186,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['131 Summer St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '322861',
#         'url': 'https://www.grubhub.com/restaurant/kashi-stamford-131-summer-st-stamford/322861?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=322861',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56ac70b2498ebfb7f369e6af-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d921fd980d3370413acac06',
#        'name': 'bartaco',
#        'location': {'address': '222 Summer St',
#         'crossStreet': 'at Broad St',
#         'lat': 41.0548752,
#         'lng': -73.5407306,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0548752,
#           'lng': -73.5407306}],
#         'distance': 232,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['222 Summer St (at Broad St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '135842521'}},
#       'referralId': 'e-0-4d921fd980d3370413acac06-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa3f4d8f964a5208c4420e3',
#        'name': 'Barcelona Wine Bar Restaurant',
#        'location': {'address': '222 Summer St',
#         'crossStreet': 'at Broad St',
#         'lat': 41.05487579081053,
#         'lng': -73.54093223620515,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05487579081053,
#           'lng': -73.54093223620515},
#          {'label': 'entrance', 'lat': 41.055086, 'lng': -73.540808}],
#         'distance': 244,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['222 Summer St (at Broad St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '131842938'}},
#       'referralId': 'e-0-4aa3f4d8f964a5208c4420e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50de12e8e4b01ebc50f9b951',
#        'name': 'Lorca',
#        'location': {'address': '125 Bedford St',
#         'lat': 41.056168300279964,
#         'lng': -73.5385170207334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.056168300279964,
#           'lng': -73.5385170207334}],
#         'distance': 305,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['125 Bedford St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '74654561'}},
#       'referralId': 'e-0-50de12e8e4b01ebc50f9b951-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4a586df964a520ab8426e3',
#        'name': "Remo's Brick Oven Pizza Company",
#        'location': {'address': '35 Bedford St',
#         'crossStreet': 'at Broad St',
#         'lat': 41.055555,
#         'lng': -73.538733,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.055555,
#           'lng': -73.538733}],
#         'distance': 236,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['35 Bedford St (at Broad St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4a586df964a520ab8426e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af63292f964a520270222e3',
#        'name': 'Connecticut Cigar Company',
#        'location': {'address': '43 Bank St',
#         'lat': 41.052657789988274,
#         'lng': -73.54033389449776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.052657789988274,
#           'lng': -73.54033389449776},
#          {'label': 'entrance', 'lat': 41.052706, 'lng': -73.539984}],
#         'distance': 159,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['43 Bank St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af63292f964a520270222e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac6952bf964a52037b520e3',
#        'name': 'Garden Catering',
#        'location': {'address': '235 Main St',
#         'lat': 41.053190911197476,
#         'lng': -73.5414101957258,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.053190911197476,
#           'lng': -73.5414101957258},
#          {'label': 'entrance', 'lat': 41.053002, 'lng': -73.541272}],
#         'distance': 226,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['235 Main St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '332568',
#         'url': 'https://www.grubhub.com/restaurant/garden-catering-235-main-st-stamford/332568?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=332568',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac6952bf964a52037b520e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59a9f912d3cce8610502ec6a',
#        'name': 'Flinders Lane',
#        'location': {'address': '184 Summer St',
#         'lat': 41.054635865275145,
#         'lng': -73.5407394584517,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.054635865275145,
#           'lng': -73.5407394584517}],
#         'distance': 215,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['184 Summer St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d169941735',
#          'name': 'Australian Restaurant',
#          'pluralName': 'Australian Restaurants',
#          'shortName': 'Australian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2030698',
#         'url': 'https://www.grubhub.com/restaurant/flinders-lane-kitchen--bar-184-summer-st-stamford/2030698?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2030698',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59a9f912d3cce8610502ec6a-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52b3904d498e1a41f5b1376e',
#        'name': 'Cask Republic',
#        'location': {'address': '191 Summer St',
#         'crossStreet': 'at Broad St',
#         'lat': 41.05465432173567,
#         'lng': -73.54066901551936,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05465432173567,
#           'lng': -73.54066901551936},
#          {'label': 'entrance', 'lat': 41.05419, 'lng': -73.540579}],
#         'distance': 212,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['191 Summer St (at Broad St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52b3904d498e1a41f5b1376e-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa412c9f964a5202d4520e3',
#        'name': 'Columbus Park Trattoria',
#        'location': {'address': '205 Main St',
#         'crossStreet': 'at Washington Blvd',
#         'lat': 41.05300374702308,
#         'lng': -73.54189129320207,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05300374702308,
#           'lng': -73.54189129320207}],
#         'distance': 269,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['205 Main St (at Washington Blvd)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1517018',
#         'url': 'https://www.grubhub.com/restaurant/columbus-park-trattoria-205-main-street-stamford/1517018?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1517018',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa412c9f964a5202d4520e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa410c9f964a5201d4520e3',
#        'name': 'The Capital Grille',
#        'location': {'address': '230 Tresser Blvd',
#         'crossStreet': 'at Stamford Town Ctr',
#         'lat': 41.05118200729633,
#         'lng': -73.53723864529758,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05118200729633,
#           'lng': -73.53723864529758}],
#         'distance': 279,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['230 Tresser Blvd (at Stamford Town Ctr)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa410c9f964a5201d4520e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ddc4093d22df17198fb0fb9',
#        'name': 'ZAZA Italian Gastrobar & Pizzeria',
#        'location': {'address': '122 Broad St',
#         'crossStreet': 'btwn Bedford & Gay St',
#         'lat': 41.05528520433702,
#         'lng': -73.53821893653004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05528520433702,
#           'lng': -73.53821893653004}],
#         'distance': 210,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['122 Broad St (btwn Bedford & Gay St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ddc4093d22df17198fb0fb9-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58af3f1e25911e5ade53707d',
#        'name': 'Fiesta on Main',
#        'location': {'address': '249 Main St',
#         'lat': 41.05323928224767,
#         'lng': -73.54124641010513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05323928224767,
#           'lng': -73.54124641010513}],
#         'distance': 211,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['249 Main St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '288506',
#         'url': 'https://www.grubhub.com/restaurant/fiesta-main-249-main-st-stamford/288506?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=288506',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58af3f1e25911e5ade53707d-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '566e4390498ef1f99a6ceba9',
#        'name': 'Acuario',
#        'location': {'address': '78 W Park Pl',
#         'lat': 41.05326633201437,
#         'lng': -73.54169002394515,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05326633201437,
#           'lng': -73.54169002394515}],
#         'distance': 248,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['78 W Park Pl',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-566e4390498ef1f99a6ceba9-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c6c699ce6b7b1f7a602a78e',
#        'name': 'Quattro Pazzi',
#        'location': {'address': '269 Bedford St',
#         'crossStreet': 'at Forest St',
#         'lat': 41.057054598107726,
#         'lng': -73.53776461486086,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.057054598107726,
#           'lng': -73.53776461486086}],
#         'distance': 411,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['269 Bedford St (at Forest St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1424462',
#         'url': 'https://www.grubhub.com/restaurant/quattro-pazzi-restaurant-269-bedford-st-stamford/1424462?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1424462',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '52626891'}},
#       'referralId': 'e-0-4c6c699ce6b7b1f7a602a78e-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb525cb6edc76b019552f1c',
#        'name': 'Salon Shahin',
#        'location': {'address': '66 Broad St',
#         'lat': 41.05559632358571,
#         'lng': -73.541004309703,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05559632358571,
#           'lng': -73.541004309703},
#          {'label': 'entrance', 'lat': 41.055559, 'lng': -73.540806}],
#         'distance': 307,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['66 Broad St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110951735',
#          'name': 'Salon / Barbershop',
#          'pluralName': 'Salons / Barbershops',
#          'shortName': 'Salon / Barbershop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84923848'}},
#       'referralId': 'e-0-4bb525cb6edc76b019552f1c-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa7f0a2f964a520194e20e3',
#        'name': 'Ferguson Library',
#        'location': {'address': '96 Broad St',
#         'crossStreet': 'at Bedford St',
#         'lat': 41.05577345576247,
#         'lng': -73.5388457177318,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05577345576247,
#           'lng': -73.5388457177318}],
#         'distance': 261,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['96 Broad St (at Bedford St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d12f941735',
#          'name': 'Library',
#          'pluralName': 'Libraries',
#          'shortName': 'Library',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa7f0a2f964a520194e20e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f32662b19836c91c7d3fb61',
#        'name': 'Cilantro Restaurant',
#        'location': {'address': '3 Landmark Sq #107',
#         'lat': 41.0548245,
#         'lng': -73.53804579999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0548245,
#           'lng': -73.53804579999999}],
#         'distance': 165,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['3 Landmark Sq #107',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1517246',
#         'url': 'https://www.grubhub.com/restaurant/cilantro-llc-3-landmark-square-stamford/1517246?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1517246',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f32662b19836c91c7d3fb61-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3535d4f964a5203e2b25e3',
#        'name': 'Avon Theater Film Center, Inc.',
#        'location': {'address': '272 Bedford St',
#         'lat': 41.05704403210361,
#         'lng': -73.53819029284362,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05704403210361,
#           'lng': -73.53819029284362}],
#         'distance': 404,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['272 Bedford St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d17e941735',
#          'name': 'Indie Movie Theater',
#          'pluralName': 'Indie Movie Theaters',
#          'shortName': 'Indie Movies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'events': {'count': 2, 'summary': '2 movies'},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36261748'}},
#       'referralId': 'e-0-4b3535d4f964a5203e2b25e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e54104a8877863330ab0c21',
#        'name': 'Franklin Street Works',
#        'location': {'address': '41 Franklin St',
#         'crossStreet': 'Broad Street',
#         'lat': 41.05689512172129,
#         'lng': -73.54134574611763,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05689512172129,
#           'lng': -73.54134574611763}],
#         'distance': 443,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['41 Franklin St (Broad Street)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '83371624'}},
#       'referralId': 'e-0-4e54104a8877863330ab0c21-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52a0bf2811d2fab33839e272',
#        'name': 'Tomatillo Taco Joint',
#        'location': {'address': '114 Broad St',
#         'lat': 41.05531439587183,
#         'lng': -73.5384353325553,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05531439587183,
#           'lng': -73.5384353325553},
#          {'label': 'entrance', 'lat': 41.055343, 'lng': -73.538427}],
#         'distance': 211,
#         'postalCode': '06905',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['114 Broad St',
#          'Stamford, CT 06905',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '286241',
#         'url': 'https://www.grubhub.com/restaurant/tomatillo-taco-joint-114-broad-st-stamford/286241?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=286241',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52a0bf2811d2fab33839e272-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4abbb7ddf964a5208f8420e3',
#        'name': 'Coromandel Cuisine of India',
#        'location': {'address': '68 Broad St',
#         'crossStreet': 'at Summer St',
#         'lat': 41.055552633037614,
#         'lng': -73.54043365321854,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.055552633037614,
#           'lng': -73.54043365321854}],
#         'distance': 275,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['68 Broad St (at Summer St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '430562',
#         'url': 'https://www.grubhub.com/restaurant/coromandel-cuisine-of-india-68-broad-st-stamford/430562?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=430562',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4abbb7ddf964a5208f8420e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbd01d3593fef3b11ef0256',
#        'name': 'Navaratna',
#        'location': {'address': '133 Atlantic St',
#         'lat': 41.0534023925787,
#         'lng': -73.53944489848615,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0534023925787,
#           'lng': -73.53944489848615},
#          {'label': 'entrance', 'lat': 41.05345, 'lng': -73.53974}],
#         'distance': 59,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['133 Atlantic St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbd01d3593fef3b11ef0256-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f8d95bae4b0a320195338f9',
#        'name': 'Dance With Me Stamford',
#        'location': {'address': '20 Summer St, Stamford, CT 06901',
#         'lat': 41.0537310064222,
#         'lng': -73.54093087439067,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0537310064222,
#           'lng': -73.54093087439067},
#          {'label': 'entrance', 'lat': 41.053423, 'lng': -73.540931}],
#         'distance': 187,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['20 Summer St, Stamford, CT 06901',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d134941735',
#          'name': 'Dance Studio',
#          'pluralName': 'Dance Studios',
#          'shortName': 'Dance Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f8d95bae4b0a320195338f9-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5011c3bfe4b0c3d590900529',
#        'name': '16 Handles',
#        'location': {'address': '219 Bedford St',
#         'crossStreet': 'at Forest St',
#         'lat': 41.05670229854188,
#         'lng': -73.53791092392521,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05670229854188,
#           'lng': -73.53791092392521}],
#         'distance': 370,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['219 Bedford St (at Forest St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '304572',
#         'url': 'https://www.grubhub.com/restaurant/16-handles-219-bedford-st-stamford/304572?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=304572',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5011c3bfe4b0c3d590900529-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3fbea1f964a520baad25e3',
#        'name': 'Barnes & Noble',
#        'location': {'address': '100 Greyrock Pl Ste H009',
#         'crossStreet': 'at Stamford Town Ctr',
#         'lat': 41.05183285354387,
#         'lng': -73.53691795430714,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05183285354387,
#           'lng': -73.53691795430714}],
#         'distance': 234,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['100 Greyrock Pl Ste H009 (at Stamford Town Ctr)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3fbea1f964a520baad25e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0a89af009a0f478b8ce9bf',
#        'name': 'Mill River Park',
#        'location': {'address': '1010 Washington Blvd',
#         'lat': 41.0537892529332,
#         'lng': -73.54513470282845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0537892529332,
#           'lng': -73.54513470282845}],
#         'distance': 538,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['1010 Washington Blvd',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0a89af009a0f478b8ce9bf-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52d571cf11d2d9f8ae1c0932',
#        'name': 'FISH Restaurant + Bar',
#        'location': {'address': '245 Bedford St',
#         'crossStreet': 'at Forest St',
#         'lat': 41.05699914175519,
#         'lng': -73.5380104296591,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05699914175519,
#           'lng': -73.5380104296591},
#          {'label': 'entrance', 'lat': 41.056842, 'lng': -73.537937}],
#         'distance': 401,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['245 Bedford St (at Forest St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2169702',
#         'url': 'https://www.grubhub.com/restaurant/fish-restaurant--bar-245-bedford-st-stamford/2169702?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2169702',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '78952123'}},
#       'referralId': 'e-0-52d571cf11d2d9f8ae1c0932-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd9f676e4b0884c8e96f741',
#        'name': 'Plan B Burger Bar',
#        'location': {'address': '230 Tresser Blvd',
#         'crossStreet': 'at Stamford Town Ctr',
#         'lat': 41.05175397361059,
#         'lng': -73.53690472815491,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05175397361059,
#           'lng': -73.53690472815491}],
#         'distance': 241,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['230 Tresser Blvd (at Stamford Town Ctr)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fd9f676e4b0884c8e96f741-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4acb7315f964a520c9c320e3',
#        'name': 'Kotobuki Japanese Cuisine',
#        'location': {'address': '427 Summer St',
#         'crossStreet': 'btwn Spring & Broad St',
#         'lat': 41.056385780778854,
#         'lng': -73.54036560213571,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.056385780778854,
#           'lng': -73.54036560213571}],
#         'distance': 356,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['427 Summer St (btwn Spring & Broad St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4acb7315f964a520c9c320e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cba38f44c60a09360fd44ca',
#        'name': 'Sushi X II',
#        'location': {'address': '109 Atlantic St',
#         'crossStreet': 'at Main St',
#         'lat': 41.05379228882797,
#         'lng': -73.53940532471017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05379228882797,
#           'lng': -73.53940532471017}],
#         'distance': 69,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['109 Atlantic St (at Main St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1516998',
#         'url': 'https://www.grubhub.com/restaurant/sushi-x-2-109-atlantic-street-stamford/1516998?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1516998',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cba38f44c60a09360fd44ca-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9c95ffd3c2b60cf6bbb8bc',
#        'name': 'Agora Spa',
#        'location': {'address': '243 Tresser Blvd',
#         'crossStreet': 'at Greyrock Pl.',
#         'lat': 41.0507930582901,
#         'lng': -73.53544860427559,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0507930582901,
#           'lng': -73.53544860427559}],
#         'distance': 402,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['243 Tresser Blvd (at Greyrock Pl.)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9c95ffd3c2b60cf6bbb8bc-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5d62af7735c9b656d18e72',
#        'name': "Stamford Downtown Farmer's Market",
#        'location': {'address': 'Bedford street',
#         'crossStreet': 'Forest street',
#         'lat': 41.05684784188281,
#         'lng': -73.53820953310682,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05684784188281,
#           'lng': -73.53820953310682}],
#         'distance': 382,
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['Bedford street (Forest street)',
#          'Stamford, CT',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5d62af7735c9b656d18e72-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5647d48a498eb7f014170b5f',
#        'name': 'SEPHORA',
#        'location': {'address': '100 Greyrock Place, Suite #E135',
#         'crossStreet': 'at Stamford Town Center',
#         'lat': 41.053143,
#         'lng': -73.536861,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.053143,
#           'lng': -73.536861}],
#         'distance': 160,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['100 Greyrock Place, Suite #E135 (at Stamford Town Center)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'shortName': 'Cosmetics',
# ...
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ef941735',
#          'name': 'Rental Car Location',
#          'pluralName': 'Rental Car Locations',
#          'shortName': 'Rental Car',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/airport_rentalcar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ccc68b5c9b84688fea6bcc3-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c642036e1621b8d40982753',
#        'name': 'Chase Bank',
#        'location': {'address': '45 Prospect St',
#         'lat': 41.0573728,
#         'lng': -73.5367366,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0573728,
#           'lng': -73.5367366}],
#         'distance': 469,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['45 Prospect St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c642036e1621b8d40982753-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f075bdee4b0aa2dc539e153',
#        'name': 'Citizens Bank',
#        'location': {'address': '59 Broad St',
#         'crossStreet': 'Broad St',
#         'lat': 41.05581833,
#         'lng': -73.54075833,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 41.055172,
#           'lng': -73.539349},
#          {'label': 'display', 'lat': 41.05581833, 'lng': -73.54075833}],
#         'distance': 315,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['59 Broad St (Broad St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f075bdee4b0aa2dc539e153-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0d3b007189c9287cb0d6b6',
#        'name': 'Juliska',
#        'location': {'address': '465 Canal St',
#         'crossStreet': 'Dock Street & Canal Street',
#         'lat': 41.04819634136911,
#         'lng': -73.53498179163533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.04819634136911,
#           'lng': -73.53498179163533}],
#         'distance': 662,
#         'postalCode': '06902',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['465 Canal St (Dock Street & Canal Street)',
#          'Stamford, CT 06902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0d3b007189c9287cb0d6b6-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5afb75a54c954c002c4a069e',
#        'name': 'Bedford Hall',
#        'location': {'lat': 41.0562186083823,
#         'lng': -73.5384364745063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.0562186083823,
#           'lng': -73.5384364745063},
#          {'label': 'entrance', 'lat': 41.056235, 'lng': -73.538432}],
#         'distance': 311,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['Stamford, CT 06901', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '985740',
#         'url': 'https://www.grubhub.com/restaurant/bedford-hall-135-bedford-st-stamford/985740?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=985740',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5afb75a54c954c002c4a069e-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bab9c27f964a520c7b83ae3',
#        'name': 'Planet Pizza - Stamford',
#        'location': {'address': '920 Summer St',
#         'crossStreet': 'at North St',
#         'lat': 41.05954123963168,
#         'lng': -73.54027859754005,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05954123963168,
#           'lng': -73.54027859754005},
#          {'label': 'entrance', 'lat': 41.059496, 'lng': -73.540371}],
#         'distance': 692,
#         'postalCode': '06905',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['920 Summer St (at North St)',
#          'Stamford, CT 06905',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '338716',
#         'url': 'https://www.grubhub.com/restaurant/planet-pizza-920-summer-st-stamford/338716?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=338716',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '382996320'}},
#       'referralId': 'e-0-4bab9c27f964a520c7b83ae3-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de00ad7d22d2a7955643db5',
#        'name': 'Budget Car Rental',
#        'location': {'address': '1 Station Plaza',
#         'lat': 41.050908,
#         'lng': -73.534221,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.050908,
#           'lng': -73.534221}],
#         'distance': 471,
#         'postalCode': '06902',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['1 Station Plaza',
#          'Stamford, CT 06902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ef941735',
#          'name': 'Rental Car Location',
#          'pluralName': 'Rental Car Locations',
#          'shortName': 'Rental Car',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/airport_rentalcar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de00ad7d22d2a7955643db5-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf3cdce98ac0f47a23263a8',
#        'name': 'Donut Delight',
#        'location': {'address': '417 Elm St',
#         'lat': 41.05008565385102,
#         'lng': -73.52769865984556,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05008565385102,
#           'lng': -73.52769865984556},
#          {'label': 'entrance', 'lat': 41.05013, 'lng': -73.527377}],
#         'distance': 998,
#         'postalCode': '06902',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['417 Elm St',
#          'Stamford, CT 06902',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1807594',
#         'url': 'https://www.grubhub.com/restaurant/donut-delight-417-elm-street-stamford/1807594?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1807594',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf3cdce98ac0f47a23263a8-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fda7e72e4b0ea76a710e73e',
#        'name': 'Hudson Grille',
#        'location': {'address': '128 Bedford St',
#         'crossStreet': 'at Spring St',
#         'lat': 41.05628658728228,
#         'lng': -73.538639286336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05628658728228,
#           'lng': -73.538639286336},
#          {'label': 'entrance', 'lat': 41.056314, 'lng': -73.53868}],
#         'distance': 318,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['128 Bedford St (at Spring St)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '51030966'}},
#       'referralId': 'e-0-4fda7e72e4b0ea76a710e73e-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc3458182388cfa1ecc6635',
#        'name': 'CVS pharmacy',
#        'location': {'address': '11 Forest St',
#         'crossStreet': 'btwn Bedford St & Greyrock Pl',
#         'lat': 41.05684789339239,
#         'lng': -73.53734482944836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.05684789339239,
#           'lng': -73.53734482944836},
#          {'label': 'entrance', 'lat': 41.056882, 'lng': -73.537299}],
#         'distance': 397,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['11 Forest St (btwn Bedford St & Greyrock Pl)',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc3458182388cfa1ecc6635-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f3aacc0bb3d2fbe725da8b9',
#        'name': 'U-Haul Neighborhood Dealer',
#        'location': {'address': '25 Jefferson St',
#         'lat': 41.048803759071355,
#         'lng': -73.53349847169386,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.048803759071355,
#           'lng': -73.53349847169386},
#          {'label': 'entrance', 'lat': 41.048954, 'lng': -73.533534}],
#         'distance': 677,
#         'postalCode': '06902',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['25 Jefferson St',
#          'Stamford, CT 06902',
#          'United States']},
#        'categories': [{'id': '4f04b1572fb6e1c99f3db0bf',
#          'name': 'Storage Facility',
#          'pluralName': 'Storage Facilities',
#          'shortName': 'Storage',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/storage_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f3aacc0bb3d2fbe725da8b9-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa3f2a2f964a520814420e3',
#        'name': "Bradford's Grill & Tavern",
#        'location': {'address': '83 Bedford St',
#         'lat': 41.055955577442575,
#         'lng': -73.53860145792531,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 41.055955577442575,
#           'lng': -73.53860145792531},
#          {'label': 'entrance', 'lat': 41.055894, 'lng': -73.538577}],
#         'distance': 281,
#         'postalCode': '06901',
#         'cc': 'US',
#         'city': 'Stamford',
#         'state': 'CT',
#         'country': 'United States',
#         'formattedAddress': ['83 Bedford St',
#          'Stamford, CT 06901',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2106679',
#         'url': 'https://www.grubhub.com/restaurant/bradfords-grill--tavern-83-bedford-st-stamford/2106679?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2106679',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '99338782'}},
#       'referralId': 'e-0-4aa3f2a2f964a520814420e3-99'}]}]}}

# %%
len(results['response']['groups'][0]['items'])
# Out:
# 100

# %%
results['response']['groups'][0]['items'][0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '56ac70b2498ebfb7f369e6af',
#   'name': 'Kashi Stamford',
#   'location': {'address': '131 Summer St',
#    'lat': 41.05431965539036,
#    'lng': -73.54061792432401,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 41.05431965539036,
#      'lng': -73.54061792432401}],
#    'distance': 186,
#    'postalCode': '06901',
#    'cc': 'US',
#    'city': 'Stamford',
#    'state': 'CT',
#    'country': 'United States',
#    'formattedAddress': ['131 Summer St',
#     'Stamford, CT 06901',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1c4941735',
#     'name': 'Restaurant',
#     'pluralName': 'Restaurants',
#     'shortName': 'Restaurant',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '322861',
#    'url': 'https://www.grubhub.com/restaurant/kashi-stamford-131-summer-st-stamford/322861?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=322861',
#    'provider': {'name': 'grubhub',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_grubhub_20180129.png'}}},
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-56ac70b2498ebfb7f369e6af-0'}

# %%
# See what keys each array entry has
results['response']['groups'][0]['items'][0].keys()
# Out:
# dict_keys(['reasons', 'venue', 'referralId'])

# %%
poi = results['response']['groups'][0]['items'][0]['venue']
poi.keys()
# Out:
# dict_keys(['id', 'name', 'location', 'categories', 'delivery', 'photos'])

# %% [markdown]
# We want to keep the following keys:
# - location.(lat, lng)  # for clustering
# - location.city  # to verify that POI is in fact in the city under search
# - location.postalCode  # for potential future analysis
# - location.address  # for posterity
# - categories.id  # for analysis
# - categories.name  # for labelling
# - categories.primary  # for checking heirarchy
# - venue.id  # for comparing and avoiding duplicates if doing multiple searches

# %%
def get_dataframe_from_results(results):
    venues = results['response']['groups'][0]['items']
    nearby_venues = json_normalize(venues) # flatten JSON
    nv = nearby_venues

    # Rename some of the columns that we want to keep
    # lat, lng
    # The we can delete 'venue'location' entries
    cols_to_keep = ['venue.name', 'venue.location.address', 'venue.location.city',
                    'venue.location.lat', 'venue.location.lng', 'venue.location.postalCode', 'venue.id']
                    #'venue.categories'] #'venue.categories.name', 'venue.categories.id', 'venue.categories.primary']
    df = nv[cols_to_keep]

    # df.loc[0]['venue.categories'][0] #['name']
    categories = [[i[0]['name'], i[0]['id']] for i in nv['venue.categories']]
    # Create a DataFrame
    df_cat = pd.DataFrame(categories)
    df_cat.columns = ['category_name', 'category_id']
    df = df.join(df_cat)

    df.rename(columns={"venue.name": "name", "venue.location.address": "address", "venue.location.city": "city",
                      "venue.location.lat": "latitude", "venue.location.lng": "longitude",
                      "venue.location.postalCode": "zipcode", "venue.id": "venue_id"}, inplace=True)
    return df

# %%
offset = 0
total_returned = 0
df = pd.DataFrame()

while True:
    url = make_url(latitude, longitude, radius, offset)
    print('Calling:', url)
    results = requests.get(url).json()
    num_available = results['response']['totalResults']
    print('num_available =', num_available)
    num_returned = len(results['response']['groups'][0]['items'])
    df_temp = get_dataframe_from_results(results)
    # print(df_temp.loc[0])
    df = df.append(df_temp, ignore_index=True)

    # Break out of loop if we have retrieved all of the entries
    offset += num_returned
    total_returned += num_returned
    print('total_returned =', total_returned)
    if total_returned >= num_available:
        break

df
# Out:
# Calling: https://api.foursquare.com/v2/venues/explore?client_id=BOGTGAFH5WKN13HQNJU0K5U3ZEUS1DLFI5JU0P2CX1ZTQGBE&client_secret=5MIOG3NT1VQ22FLEJPQJ1RND2QAFVF5QEMBXATCLXNHOOBRZ&v=20180605&ll=41.0534302,-73.5387341&radius=1000&offset=0&limit=100&time=any&day=any
# num_available = 120
# total_returned = 100
# Calling: https://api.foursquare.com/v2/venues/explore?client_id=BOGTGAFH5WKN13HQNJU0K5U3ZEUS1DLFI5JU0P2CX1ZTQGBE&client_secret=5MIOG3NT1VQ22FLEJPQJ1RND2QAFVF5QEMBXATCLXNHOOBRZ&v=20180605&ll=41.0534302,-73.5387341&radius=1000&offset=100&limit=100&time=any&day=any
# num_available = 120
# total_returned = 120
#                                         name  \
# 0                             Kashi Stamford
# 1                                    bartaco
# 2              Barcelona Wine Bar Restaurant
# 3                                      Lorca
# 4            Remo's Brick Oven Pizza Company
# 5                  Connecticut Cigar Company
# 6                            Garden Catering
# 7                              Flinders Lane
# 8                              Cask Republic
# 9                    Columbus Park Trattoria
# 10                        The Capital Grille
# 11         ZAZA Italian Gastrobar & Pizzeria
# 12                            Fiesta on Main
# 13                                   Acuario
# 14                             Quattro Pazzi
# 15                              Salon Shahin
# 16                          Ferguson Library
# 17                       Cilantro Restaurant
# 18            Avon Theater Film Center, Inc.
# 19                     Franklin Street Works
# 20                      Tomatillo Taco Joint
# 21               Coromandel Cuisine of India
# 22                                 Navaratna
# 23                    Dance With Me Stamford
# 24                                16 Handles
# 25                            Barnes & Noble
# 26                           Mill River Park
# 27                     FISH Restaurant + Bar
# 28                         Plan B Burger Bar
# 29                 Kotobuki Japanese Cuisine
# 30                                Sushi X II
# 31                                 Agora Spa
# 32         Stamford Downtown Farmer's Market
# 33                                   SEPHORA
# 34        Lucky's Classic Burger & Malt Shop
# 35                                   PANDORA
# 36                           Tigin Irish Pub
# 37                              Barrel House
# 38                                Kona Grill
# 39                      American Eagle Store
# 40                          Siena Ristorante
# 41                         Saks Fifth Avenue
# 42                             Columbus Park
# 43                              Seasons Eats
# 44                         Pieology Pizzeria
# 45                            Capriccio Cafe
# 46        Fuji Japanese & Chinese Restaurant
# 47                         Eos Greek Cuisine
# 48              The Original Pappas Pizzeria
# 49   Courtyard by Marriott Stamford Downtown
# 50                              Kyushu Ramen
# 51                   Murphy's Townhouse Cafe
# 52         Bobby V's Restaurant & Sports Bar
# 53               Chutni Biryani & Noodle Bar
# 54                                      Teff
# 55                                    Target
# 56                              Pottery Barn
# 57                   Brick House Bar & Grill
# 58                              Alive @ Five
# 59                      Stamford Town Center
# 60                         Wetzel's Pretzels
# 61                              Michael Kors
# 62             Fernando Luis Alvarez Gallery
# 63                                Forever 21
# 64                                Casa Villa
# 65                       Brother Jimmy's BBQ
# 66                              Colony Grill
# 67                          Caribbean Bakery
# 68              Ocha Thai & Japanese Cuisine
# 69                            Fairway Market
# 70                   Villa Italia Ristorante
# 71                              John's Pizza
# 72                      Roasted Sandwich Co.
# 73               Totally Tip - Toe Nails Spa
# 74                      Bedford Street Diner
# 75                   Sheraton Stamford Hotel
# 76                   Fairway Wines & Spirits
# 77                          Matthew's Bakery
# 78                               Dairy Queen
# 79                          Chez Vous Bistro
# 80                                   Dunkin'
# 81             Stamford Marriott Hotel & Spa
# 82                              CVS pharmacy
# 83                                 Wedge Inn
# 84                          BonJo Coffee Bar
# 85                     Pellicci's Ristorante
# 86                                 Bar Rosso
# 87                         Pedigree Ski Shop
# 88                       National Car Rental
# 89                                Chase Bank
# 90                             Citizens Bank
# 91                                   Juliska
# 92                              Bedford Hall
# 93                   Planet Pizza - Stamford
# 94                         Budget Car Rental
# 95                             Donut Delight
# 96                             Hudson Grille
# 97                              CVS pharmacy
# 98                U-Haul Neighborhood Dealer
# 99                 Bradford's Grill & Tavern
# 100                                  Dunkin'
# 101                         Alamo Rent A Car
# 102                 Arts & Crafts On Bedford
# 103                    Enterprise Rent-A-Car
# 104                                  Cantina
# 105                   Northern Lights Lounge
# 106                                Walgreens
# 107                                  Dunkin'
# 108                         Elixir Juice Bar
# 109                                 Rite Aid
# 110                          Stamford Suites
# 111                          Gym @ ParcGrove
# 112                                Taco Bell
# 113                                  Dunkin'
# 114                           China Pavilion
# 115                     For Your Convenience
# 116                  Scotty's Fish and Chips
# 117                      Revolution Training
# 118                      Ladi's Unisex Salon
# 119          111 Harbor Point Fitness Center
#
#                               address      city   latitude  longitude zipcode  \
# 0                       131 Summer St  Stamford  41.054320 -73.540618   06901
# 1                       222 Summer St  Stamford  41.054875 -73.540731   06901
# 2                       222 Summer St  Stamford  41.054876 -73.540932   06901
# 3                      125 Bedford St  Stamford  41.056168 -73.538517   06901
# 4                       35 Bedford St  Stamford  41.055555 -73.538733   06901
# 5                          43 Bank St  Stamford  41.052658 -73.540334   06901
# 6                         235 Main St  Stamford  41.053191 -73.541410   06901
# 7                       184 Summer St  Stamford  41.054636 -73.540739   06901
# 8                       191 Summer St  Stamford  41.054654 -73.540669   06901
# 9                         205 Main St  Stamford  41.053004 -73.541891   06901
# 10                   230 Tresser Blvd  Stamford  41.051182 -73.537239   06901
# 11                       122 Broad St  Stamford  41.055285 -73.538219   06901
# 12                        249 Main St  Stamford  41.053239 -73.541246   06901
# 13                       78 W Park Pl  Stamford  41.053266 -73.541690   06901
# 14                     269 Bedford St  Stamford  41.057055 -73.537765   06901
# 111                      200 Broad St  Stamford  41.055962 -73.534409   06901
# 112                     751 E Main St  Stamford  41.055253 -73.529789   06902
# 113                        310 Elm St  Stamford  41.051640 -73.529064   06902
# 114                     67 W Broad St  Stamford  41.055905 -73.547784   06902
# 115                   135 Prospect St  Stamford  41.060027 -73.533941   06901
# 116                       70 Smith St  Stamford  41.052390 -73.548910   06902
# 117                    579 Pacific St  Stamford  41.045394 -73.537839   06902
# 118                     805 E Main St  Stamford  41.054794 -73.528114   06902
# 119                      111 Towne St  Stamford  41.045088 -73.536461   06902
#
#                      venue_id              category_name  \
# 0    56ac70b2498ebfb7f369e6af                 Restaurant
# 1    4d921fd980d3370413acac06         Mexican Restaurant
# 2    4aa3f4d8f964a5208c4420e3         Spanish Restaurant
# 3    50de12e8e4b01ebc50f9b951                Coffee Shop
# 4    4b4a586df964a520ab8426e3                Pizza Place
# 5    4af63292f964a520270222e3                     Lounge
# 6    4ac6952bf964a52037b520e3              Deli / Bodega
# 7    59a9f912d3cce8610502ec6a      Australian Restaurant
# 8    52b3904d498e1a41f5b1376e                  Gastropub
# 9    4aa412c9f964a5202d4520e3         Italian Restaurant
# 10   4aa410c9f964a5201d4520e3        American Restaurant
# 11   4ddc4093d22df17198fb0fb9         Italian Restaurant
# 12   58af3f1e25911e5ade53707d  Latin American Restaurant
# 13   566e4390498ef1f99a6ceba9  Latin American Restaurant
# 14   4c6c699ce6b7b1f7a602a78e         Italian Restaurant
# 15   4bb525cb6edc76b019552f1c         Salon / Barbershop
# 16   4aa7f0a2f964a520194e20e3                    Library
# 17   4f32662b19836c91c7d3fb61  Latin American Restaurant
# 18   4b3535d4f964a5203e2b25e3        Indie Movie Theater
# 19   4e54104a8877863330ab0c21                Art Gallery
# 20   52a0bf2811d2fab33839e272                 Taco Place
# 21   4abbb7ddf964a5208f8420e3          Indian Restaurant
# 22   4bbd01d3593fef3b11ef0256          Indian Restaurant
# 23   4f8d95bae4b0a320195338f9               Dance Studio
# 24   5011c3bfe4b0c3d590900529             Ice Cream Shop
# 25   4b3fbea1f964a520baad25e3                  Bookstore
# 26   4c0a89af009a0f478b8ce9bf                       Park
# 27   52d571cf11d2d9f8ae1c0932         Seafood Restaurant
# 28   4fd9f676e4b0884c8e96f741               Burger Joint
# 29   4acb7315f964a520c9c320e3        Japanese Restaurant
# 30   4cba38f44c60a09360fd44ca           Sushi Restaurant
# 31   4c9c95ffd3c2b60cf6bbb8bc                        Spa
# 32   4c5d62af7735c9b656d18e72             Farmers Market
# 33   5647d48a498eb7f014170b5f             Cosmetics Shop
# 34   4b4d2ddbf964a52079cd26e3               Burger Joint
# 35   4b6dda42f964a520d6952ce3              Jewelry Store
# 36   4a6286a6f964a5203dc41fe3                        Pub
# 37   567f4c64498e6a84eb4a886c         Italian Restaurant
# 38   4b5637e4f964a520e10528e3           Sushi Restaurant
# 39   4bbca1fb593fef3bf85f0256             Clothing Store
# 40   4beb51266295c9b6c7a38708         Italian Restaurant
# 41   559acdae498ea6e88f5953f8           Department Store
# 42   4c3e4979b8b4be9a57f4cbef                      Plaza
# 43   4b643d0ef964a520c2a52ae3        American Restaurant
# 44   58efbc361213841f7339cda3                Pizza Place
# 45   4b02080ef964a520544722e3         Italian Restaurant
# 46   4f32492b19836c91c7c8ae2f         Chinese Restaurant
# 47   4bb52e922f70c9b664df8330           Greek Restaurant
# 48   4baaab0cf964a520567e3ae3                Pizza Place
# 49   4bb2afb642959c745f38212c                      Hotel
# 50   59a993af46e1b601b164b10a           Ramen Restaurant
# 51   4b50de02f964a520083627e3                 Restaurant
# 52   59306fe459fe5c3951007249                 Sports Bar
# 53   589f6abd92789f6a81075c90          Indian Restaurant
# 54   54639bdb498e7ea222c74ec2       Ethiopian Restaurant
# 55   4adb55c4f964a5200d2621e3              Big Box Store
# 56   4b5c78d3f964a5206c3129e3     Furniture / Home Store
# 57   4aa3f99ff964a520a54420e3                        Bar
# 58   4c21fd77aa8e9c744a5af4d4                Music Venue
# 59   4aad2132f964a520a25e20e3              Shopping Mall
# 60   4b6da2def964a52038822ce3                Snack Place
# 61   51b23cee7dd2a980cdfb9dc0                   Boutique
# 62   4c3f353ada3dc9289083c5b9                Art Gallery
# 63   4b85b619f964a520716e31e3             Clothing Store
# 64   4abf8e58f964a520159120e3         Mexican Restaurant
# 65   551dd956498eaa1b748c6a77                  BBQ Joint
# 66   4aa2e26ff964a5206a4220e3                Pizza Place
# 67   4c2e318be116e21e67e28f60       Caribbean Restaurant
# 68   4b2ebfbff964a5201fe624e3            Thai Restaurant
# 69   4cd15ef806b546882932e094                Supermarket
# 70   4b905ee0f964a5209b8633e3         Italian Restaurant
# 71   4b91b28cf964a520a9d033e3                Pizza Place
# 72   5a7600d523a2e630fce5035d             Sandwich Place
# 73   4da486de9aa4721e50c9391a                        Spa
# 74   4b52085ef964a520bb6227e3                      Diner
# 75   4de414a763655ed7e40c3a52                      Hotel
# 76   4d534775b3d9a35db159c17b               Liquor Store
# 77   4bc0933af8219c749ebcb110                     Bakery
# 78   4ba3d408f964a520f16338e3             Ice Cream Shop
# 79   5674cdf1498eb9c89c9d04f7          French Restaurant
# 80   4ee76ed30e61681b98fd3d1d                 Donut Shop
# 81   4aaa46f5f964a520a95520e3                      Hotel
# 82   559c4910498e491b86168f60                   Pharmacy
# 83   4bd1deeb9854d13a1369fa4d             Sandwich Place
# 84   51a770fb498e754421650f21                Coffee Shop
# 85   4b36573af964a5202e3325e3         Italian Restaurant
# 86   4dbf498afa8cc78a860efaca         Italian Restaurant
# 87   4bb75ce7ef159c74b71277f7                   Ski Shop
# 88   4ccc68b5c9b84688fea6bcc3        Rental Car Location
# 89   4c642036e1621b8d40982753                       Bank
# 90   4f075bdee4b0aa2dc539e153                       Bank
# 91   4c0d3b007189c9287cb0d6b6     Furniture / Home Store
# 92   5afb75a54c954c002c4a069e        American Restaurant
# 93   4bab9c27f964a520c7b83ae3                Pizza Place
# 94   4de00ad7d22d2a7955643db5        Rental Car Location
# 95   4bf3cdce98ac0f47a23263a8                Coffee Shop
# 96   4fda7e72e4b0ea76a710e73e    New American Restaurant
# 97   4cc3458182388cfa1ecc6635                   Pharmacy
